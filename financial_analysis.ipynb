# %%
import numpy as np #importing numpy pkg
import pandas as pd #importing pandas pkg
import yfinance as yf # Yahoo API for stock market
import plotly.graph_objs as go #Data Viz

# %%
symbol = ['MYTIL.AT'] #sets Mytilineos as a ticker for the analysis
data1 = yf.download(tickers= symbol, period= '5y', interval='3mo') # Mytilineos Stock for 1 month into 1 day interval
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data1 #prints Mytilineos's stock market values
data1.to_excel("mytil_at_stock.xlsx") #exports to Excel stock market values

# %%
mytil_at = yf.Ticker('MYTIL.AT')
mytil_at = tesla.history(period="5y", interval="3mo") 
mytil_at['Close'].plot(title="Mytilineos's stock price") #prints a plot for Mytilineos stock price for 5 years
# Out:
# <AxesSubplot:title={'center':"Mytilineos's stock price"}, xlabel='Date'>

# %%
mytil_at = yf.Ticker('MYTIL.AT')
mytil_at.major_holders #shows Mytilineos's Shareholders
# Out:
#         0                                      1
# 0  26.54%        % of Shares Held by All Insider
# 1  15.93%       % of Shares Held by Institutions
# 2  21.69%        % of Float Held by Institutions
# 3      84  Number of Institutions Holding Shares

# %%
mytil_at.institutional_holders #shows Mytilineos's Institutional Shareholders
# Out:
#                                               Holder   Shares Date Reported  \
# 0  Vanguard International Stock Index-Emerging Ma...  1507566    2021-07-31
# 1              Fidelity International Small Cap Fund  1472216    2021-08-31
# 2  Vanguard International Stock Index-Total Intl ...  1452466    2021-07-31
# 3             iShares Core MSCI Emerging Markets ETF   812244    2021-09-30
# 4       Fidelity Series Intrinsic Opportunities Fund   800000    2021-08-31
# 5       Fidelity Series International Small Cap Fund   460000    2021-08-31
# 6  DFA Investment Dimensions-DFA Emerging Mkts Value   382362    2021-07-31
# 7              Global X Fds-Global X MSCI Greece ETF   294062    2021-09-30
# 8         DFA Emerging Markets Core Equity Portfolio   289423    2021-07-31
# 9  Vanguard Intl Equity Index Fds-FTSE All World ...   239986    2021-07-31
#
#     % Out     Value
# 0  0.0106  23578332
# 1  0.0103  23408234
# 2  0.0102  22716568
# 3  0.0057  11452640
# 4  0.0056  12720000
# ...

# %%
mytil_at = yf.Ticker('MYTIL.AT')
hist = mytil_at.history(period="1mo", interval="1h")
hist #prints Mytilineos's
# Out:
#                             Open   High    Low  Close  Volume  Dividends  \
# 2021-10-06 10:30:00+03:00  14.58  14.58  14.36  14.49   60496          0
# 2021-10-06 11:30:00+03:00  14.50  14.60  14.43  14.43   18541          0
# 2021-10-06 12:30:00+03:00  14.43  14.44  14.34  14.34   11416          0
# 2021-10-06 13:30:00+03:00  14.34  14.40  14.32  14.37   16097          0
# 2021-10-06 14:30:00+03:00  14.38  14.54  14.38  14.50   27033          0
# ...                          ...    ...    ...    ...     ...        ...
# 2021-11-05 12:30:00+02:00  15.30  15.36  15.28  15.32   13048          0
# 2021-11-05 13:30:00+02:00  15.32  15.32  15.25  15.27   16309          0
# 2021-11-05 14:30:00+02:00  15.27  15.37  15.25  15.34   30798          0
# 2021-11-05 15:30:00+02:00  15.34  15.38  15.32  15.35   13949          0
# 2021-11-05 16:30:00+02:00  15.34  15.39  15.31  15.31   26109          0
#
#                            Stock Splits
# 2021-10-06 10:30:00+03:00             0
# ...

# %%
mytil_at_balance_sheet = mytil_at.balance_sheet
mytil_at_balance_sheet #prints Mitilineos's Balance Sheet between 2017 and 2020

# %%
mytil_at_balance_sheet.to_excel("mytil_at_balance_sheet.xlsx") #exports to MS Excel Mitilineos's Balance Sheet
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets                 2.317350e+08  2.317580e+08  2.352770e+08
# Capital Surplus                   1.952230e+08  1.933120e+08  1.933120e+08
# Total Liab                        2.417791e+09  2.524049e+09  1.779945e+09
# Total Stockholder Equity          1.510949e+09  1.584344e+09  1.508378e+09
# Minority Interest                 6.309700e+07  4.952600e+07  5.267100e+07
# Other Current Liab                5.216080e+08  4.668140e+08  4.813050e+08
# Total Assets                      3.991837e+09  4.157919e+09  3.340994e+09
# Common Stock                      1.388390e+08  1.388390e+08  1.388390e+08
# Other Current Assets              1.681370e+08  9.422600e+07  7.313700e+07
# Retained Earnings                 1.273555e+09  1.247115e+09  1.149060e+09
# Other Liab                        3.477490e+08  3.245470e+08  3.749710e+08
# ...

# %%
mytil_at_cashflow = mytil_at.cashflow
mytil_at_cashflow
# Out:
#                                             2020-12-31   2019-12-31  \
# Change To Liabilities                              0.0          0.0
# Total Cashflows From Investing Activities -207813000.0 -122006000.0
# Net Borrowings                            -103125000.0  475827000.0
# Total Cash From Financing Activities      -263208000.0  383248000.0
# Change To Operating Activities              46434000.0  234616000.0
# Net Income                                 128926000.0  144891000.0
# Change In Cash                            -220391000.0  504947000.0
# Effect Of Exchange Rate                      2286000.0    -297000.0
# Total Cash From Operating Activities       248344000.0  244003000.0
# Depreciation                                93413000.0   97310000.0
# Other Cashflows From Investing Activities  -32436000.0    9627000.0
# Dividends Paid                             -49549000.0  -52072000.0
# Change To Inventory                        -79560000.0  -22973000.0
# ...
